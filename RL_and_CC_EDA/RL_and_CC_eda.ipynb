# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Prep of The Datasets

# %%
## Prep of the Rule of Law Data ##

filter = ['Country Name','2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
 '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
 '2018', '2019', '2020']
rl_df = pd.read_csv("API_RL.PER.RNK_DS2_en_csv_v2_27865.csv")
rl = rl_df[filter]
rl.head()
# Out:
#                   Country Name      2000  2001      2002      2003       2004  \
# 0                        Aruba       NaN   NaN       NaN       NaN  80.769234
# 1  Africa Eastern and Southern       NaN   NaN       NaN       NaN        NaN
# 2                  Afghanistan  1.492537   NaN  1.990050  2.985075   2.403846
# 3   Africa Western and Central       NaN   NaN       NaN       NaN        NaN
# 4                       Angola  2.487562   NaN  2.487562  5.970149   5.288462
#
#         2005       2006       2007       2008  ...       2011       2012  \
# 0  77.990433  72.727272  75.119614  76.442307  ...  88.262909  87.323944
# 1        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 2   2.392344   0.478469   0.478469   0.480769  ...   0.469484   1.408451
# 3        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 4   6.220096   8.133971   6.220096   7.211538  ...   8.920188   7.511737
#
# ...

# %%
## Prep of the Control of Corruption Data ##

cc_df = pd.read_csv("API_CC.PER.RNK_DS2_en_csv_v2_21140.csv")
cc = cc_df[filter]
cc.head()
# Out:
#                   Country Name      2000  2001      2002      2003       2004  \
# 0                        Aruba       NaN   NaN       NaN       NaN  85.221672
# 1  Africa Eastern and Southern       NaN   NaN       NaN       NaN        NaN
# 2                  Afghanistan  4.787234   NaN  4.761905  4.761905   6.403941
# 3   Africa Western and Central       NaN   NaN       NaN       NaN        NaN
# 4                       Angola  8.510638   NaN  7.936508  5.291005   5.911330
#
#         2005       2006       2007       2008  ...       2011       2012  \
# 0  88.292686  88.292686  88.349518  87.378639  ...  82.938385  82.464455
# 1        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 2   1.463415   1.951220   0.970874   0.485437  ...   0.473934   1.421801
# 3        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 4   6.341464   7.804878   5.339806   4.368932  ...   3.317536   4.739336
#
# ...

# %% [markdown]
# ### Analysis of Turkey

# %%
rl_turkey = rl[rl['Country Name'] == 'Turkiye']
cc_turkey = cc[cc['Country Name'] == 'Turkiye']

# %%
years = rl_turkey.columns[1:].astype(int)
years
# Out:
# Index([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#       dtype='int64')

# %%
rl_values = rl_turkey.values[:,1:][0]
rl_values[1] = (rl_values[0] + rl_values[2]) / 2 #imputing the nan value with the avarage of the previous and the next values
rl_values
# Out:
# array([49.2537307739258, 49.5024871826172, 49.7512435913086,
#        55.2238807678223, 57.211540222168, 56.4593315124512,
#        53.1100463867188, 53.5885162353516, 55.288459777832,
#        56.3981056213379, 54.9763031005859, 55.8685455322266,
#        54.4600944519043, 54.4600944519043, 54.8076934814453,
#        47.6190490722656, 40.0, 41.4285697937012, 38.0952377319336,
#        40.9523811340332, 37.6190490722656], dtype=object)

# %%
cc_values = cc_turkey.values[:,1:][0]
cc_values[1] = (cc_values[0] + cc_values[2]) / 2 #imputing the nan value with the avarage of the previous and the next values
cc_values
# Out:
# array([46.8085098266602, 40.86457252502445, 34.9206352233887,
#        49.7354507446289, 50.2463035583496, 56.0975608825684,
#        57.5609741210938, 59.2233009338379, 61.1650466918945,
#        60.2870826721191, 59.0476188659668, 58.7677726745605,
#        61.6113739013672, 60.6635055541992, 53.8461532592773,
#        52.3809509277344, 50.0, 48.0952377319336, 42.8571434020996,
#        42.8571434020996, 41.9047622680664], dtype=object)

# %%
plt.Figure(figsize=(10,8))
plt.title("Rule of Law and Control of Corruption percentile Rank of Turkiye over the Years")
plt.plot(years, rl_values, label='Rule of Law % Rank',color='teal')
plt.xticks(years, rotation=90)

plt.plot(years, cc_values, label= 'control of Corruption % Rank', color='orange')


plt.legend()
plt.show()
